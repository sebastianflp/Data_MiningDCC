# %% [markdown]
# # Proyecto semestral: Análisis exploración de datos

# %% [markdown]
# ### 1. Introducción

# %% [markdown]
# El presente reporte tiene el objetivo de dar a conocer el conjunto de datos con los que se trabajará a lo largo del semestre, además de realizar distintos tipos de análisis gráficos que aporten información valiosa dirigida al próximo análisis mediante modelos estadísticos.
#
# El dataset que se usa contienen información respecto a la reservación de hoteles, ya sea resort o en la ciudad durante los años 2015-2017. Entre la información incluida se tiene la fecha en la que fue hecha la reservación, el tiempo de estadía, la distribución de los reservantes (el número de adultos, niños y bebés) y el número de estacionamientos reservados, entre otras cosas.
#
# #### 1.1 Objetivos
# El objetivo es predecir una cancelación en la reserva de acuerdo a la información de dicha reserva. Paralelamente se pretende obtener una caracterización de los clientes que son más propensos a cancelar sus reservas.

# %% [markdown]
# ### 2. Exploración de datos

# %% [markdown]
# El primer alcance con el proyecto fue un análisis exploratorio de datos. Se comenzó estudiando superficialmente el tipo de cada variable. También ser revisó la cantidad de datos faltantes.

# %% [markdown]
# ### 3. Preguntas y problemas

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=e23c1f0e-bfe3-498a-84d7-0763e07e74ab' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
